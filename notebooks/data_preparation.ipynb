# %% [markdown]
# # Data Preparation

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1. Create the variable `csv_path`, which stores the path to your `"csv" folder` as a string

# %%
### 1. Create the variable `csv_path`, which stores the path to your `"csv" folder` as a string
from pathlib import Path
csv_path = Path("/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv").expanduser()
csv_path
# Out:
# PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv')

# %%
file_paths = list(csv_path.iterdir())
file_paths
# Out:
# [PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_sellers_dataset.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/product_category_name_translation.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_orders_dataset.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_order_items_dataset.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_customers_dataset.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_geolocation_dataset.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_order_payments_dataset.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_order_reviews_dataset.csv'),
#  PosixPath('/Users/gechen/Projects/OlistDataAnalysis/OlistData/data/csv/olist_products_dataset.csv')]

# %%
# load the first csv in the directory
import pandas as pd
pd.read_csv(file_paths[0]).head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
### 2. Create the list `file_names` containing all csv file names in the csv directory
'''- It should look like this `file_names = ['olist_sellers_dataset.csv', ....]`
- You can start from `file_paths`
- A `Path` has a `name`  property'''

file_names = [f.name for f in file_paths]
file_names
# Out:
# ['olist_sellers_dataset.csv',
#  'product_category_name_translation.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv']

# %%
### 3.  Create the list of dict key `key_names`
"""Starting from file_names and:
- Removing its suffix ".csv" when it exists
- Removing its suffix "_dataset.csv" when it exists
- Removing its prefix "olist_" when it exists
"""
key_names = [key_name
    .replace('olist_','')
    .replace('_dataset','')
    .replace('.csv','')
    for key_name in file_names]
key_names
# Out:
# ['sellers',
#  'product_category_name_translation',
#  'orders',
#  'order_items',
#  'customers',
#  'geolocation',
#  'order_payments',
#  'order_reviews',
#  'products']

# %%
### 4. Construct the dictionary `data`
''''''
data = {}
for key, file_path in zip(key_names, file_paths):
    data[key] = pd.read_csv(file_path)
data.keys()
# Out:
# dict_keys(['sellers', 'product_category_name_translation', 'orders', 'order_items', 'customers', 'geolocation', 'order_payments', 'order_reviews', 'products'])

# %%
### 5. Implement the method `get_data()` in `olist/data.py`
from olistClass.data import Olist
Olist().get_data()['sellers'].head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
